# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WineQT.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
print(f"{float(df["quality"].mean())} is quality mean ")
# Out:
# 5.657042869641295 is quality mean

# %%
df["fixed acidity"].value_counts()
# Out:
# fixed acidity
# 7.2     43
# 7.1     41
# 7.8     40
# 7.0     40
# 7.5     37
#         ..
# 14.3     1
# 15.9     1
# 11.8     1
# 4.9      1
# 5.7      1
# Name: count, Length: 91, dtype: int64

# %%
df.groupby("quality")["alcohol"].mean()
# Out:
# quality
# 3     9.691667
# 4    10.260606
# 5     9.902277
# 6    10.655339
# 7    11.482634
# 8    11.937500
# Name: alcohol, dtype: float64

# %%
# Histplot → Alkol dağılımı
sns.histplot(df["alcohol"], kde=True)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
# Boxplot → Outlier kontrolü
sns.boxplot(x="quality", y="alcohol", data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.pairplot(df, vars=["alcohol", "pH", "sulphates", "quality"], hue="quality")

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
sns.boxplot(x="quality", y="volatile acidity",hue="quality", data=df)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.countplot(x="quality",hue="alcohol",data=df)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
print("Ortalama kalite:", df["quality"].mean())
print("En düşük kalite:", df["quality"].min())
print("En yüksek kalite:", df["quality"].max())
# Out:
# Ortalama kalite: 5.657042869641295
# En düşük kalite: 3
# En yüksek kalite: 8

# %%
# Kalite dağılımı (kaç tane 5, 6, 7 var vs.)
sns.countplot(x="quality", data=df)
plt.title("Şarap Kalite Dağılımı")
plt.show()

# %%
# Alkol dağılımı
sns.histplot(df["alcohol"], kde=True, bins=30, color="purple")
plt.title("Alkol Dağılımı")
plt.show()

# %%
# Boxplot - Kaliteye göre alkol
sns.boxplot(x="quality", y="alcohol", data=df)
plt.title("Kaliteye Göre Alkol Dağılımı")
plt.show()

# %%
# Korelasyon matrisi (ısı haritası)
plt.figure(figsize=(10,8))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korelasyon Matrisi")
plt.show()

# %%
# Pairplot (bazı önemli özellikler vs kalite)
sns.pairplot(df, vars=["alcohol", "pH", "sulphates", "density"], hue="quality", palette="husl")
plt.show()

# %%
def alcohol_category(x):
    if x < 10:
        return "Low"
    elif 10 <= x < 12:
        return "Medium"
    else:
        return "High"

df["alcohol_category"] = df["alcohol"].apply(alcohol_category)

# %%
df["quality_label"] = df["quality"].apply(lambda q: "Good" if q >= 7 else "Bad")

# %%
df["acidity_level"] = df["pH"].apply(lambda x: "Low" if x < 3.2 else ("Medium" if x < 3.4 else "High"))

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Alkol kategorisine göre kalite dağılımı
sns.countplot(x="alcohol_category", hue="quality_label", data=df, palette="Set1")
plt.title("Alkol Seviyesi vs Kalite")
plt.show()

# %%
# Kaliteye göre acidity_level
sns.countplot(x="acidity_level", hue="quality_label", data=df, palette="Set2")
plt.title("Asitlik Seviyesi vs Kalite")
plt.show()

# %%
# Pie chart - Good vs Bad wines
df["quality_label"].value_counts().plot.pie(autopct="%1.1f%%", startangle=90, colors=["lightcoral","lightgreen"])
plt.title("İyi vs Kötü Şarapların Dağılımı")
plt.ylabel("")  # y-axis yazısını kaldır
plt.show()
